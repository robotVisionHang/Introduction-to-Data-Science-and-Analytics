# %% [markdown]
# ### Building a Convolutional Neural Network
# This notebook is a brief guide to using TensorFlow's layers modules to build a convolutional neural network
# model to recognize the handwritten digits in the MNIST data set, which contains 60,000 training
# examples and 10,000 test examples of the handwritten digits 0–9, stored as 28x28-pixel black-and-white images.
#
# The layers module provides methods that facilitate the creation of convolutional neural networks with fully
# connected layers and convolutional layers, adding activation functions, and applying dropout regularization.
#
# Convolutional neural networks (CNNs) are an architecture for image classification tasks consisting of a series
# of filters that are applied to images represented as pixel vectors to extract (and learn) higher-level features,
# which can later be used for classification.
#
# A CNN contains three components:
#  - Convolutional layers, each of which applies a specified convolution filter to the image. Each layer encodes subregions of the image as a single value to be stored in the output feature map.
# - Pooling layers, which reduce the dimensionality of the feature map by using non-linear functions (e.g., max-pooling, average-pooling, etc.). Max pooling partitions the input image into a set of non-overlapping rectangles (e.g., 2x2-pixel regions) and, for each such rectangle, outputs the maximum, thus reducing the spatial size of the representation and hence the amount of computation needed in the network. This also helps control overfitting. Pooling layers are commonly inserted between successive convolutional layers.
# - Fully-connected layers (where every node in the layer is connected to every node in the preceding layer), which perform classification on the features extracted by the convolutional layers.
#
# Each CNN is composed of a stack of modules where each module consists of a convolutional layer followed by a pooling layer, together performing feature extraction. The last convolutional module is linked to one or more fully-connected (i.e., dense) layers that perform classification. The last dense layer in a CNN contains a single node for each of the possible classes the model may predict, with a softmax activation function to generate a value between 0–1 for each node.  The softmax values for a given image are interpreted as a measure of how likely it is that the image belongs to each of the possible classes. (The sum of all the softmax values is equal to 1.)
#
# Let's start by importing the necessary modules.

# %%
# !pip install --upgrade tensorflow
# Out:
# ^C

# %%
import tensorflow as tf

# Import MNIST data
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("/tmp/data/", one_hot=True)
# Out:
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz

# %%
# Parameters
learning_rate = 0.001
training_iters = 200000
batch_size = 128
display_step = 10

# Network Parameters
n_input = 784 # MNIST data input (img shape: 28*28)
n_classes = 10 # MNIST total classes (0-9 digits)
dropout = 0.75 # Dropout, probability to keep units

# tf Graph input
x = tf.placeholder(tf.float32, [None, n_input])
y = tf.placeholder(tf.float32, [None, n_classes])
keep_prob = tf.placeholder(tf.float32) #dropout (keep probability)

# %%
# Create some wrappers for simplicity
def conv2d(x, W, b, strides=1):
    # Conv2D wrapper, with bias and relu activation
    x = tf.nn.conv2d(x, W, strides=[1, strides, strides, 1], padding='SAME')
    x = tf.nn.bias_add(x, b)
    return tf.nn.relu(x)


def maxpool2d(x, k=2):
    # MaxPool2D wrapper
    return tf.nn.max_pool(x, ksize=[1, k, k, 1], strides=[1, k, k, 1],
                          padding='SAME')


# Create model
def conv_net(x, weights, biases, dropout):
    # Reshape input picture
    x = tf.reshape(x, shape=[-1, 28, 28, 1])

    # Convolution Layer
    conv1 = conv2d(x, weights['wc1'], biases['bc1'])
    # Max Pooling (down-sampling)
    conv1 = maxpool2d(conv1, k=2)

    # Convolution Layer
    conv2 = conv2d(conv1, weights['wc2'], biases['bc2'])
    # Max Pooling (down-sampling)
    conv2 = maxpool2d(conv2, k=2)

    # Fully connected layer
    # Reshape conv2 output to fit fully connected layer input
    fc1 = tf.reshape(conv2, [-1, weights['wd1'].get_shape().as_list()[0]])
    fc1 = tf.add(tf.matmul(fc1, weights['wd1']), biases['bd1'])
    fc1 = tf.nn.relu(fc1)
    # Apply Dropout
    fc1 = tf.nn.dropout(fc1, dropout)

    # Output, class prediction
    out = tf.add(tf.matmul(fc1, weights['out']), biases['out'])
    return out

# %%
# Store layers weight & bias
weights = {
    # 5x5 conv, 1 input, 32 outputs
    'wc1': tf.Variable(tf.random_normal([5, 5, 1, 32])),
    # 5x5 conv, 32 inputs, 64 outputs
    'wc2': tf.Variable(tf.random_normal([5, 5, 32, 64])),
    # fully connected, 7*7*64 inputs, 1024 outputs
    'wd1': tf.Variable(tf.random_normal([7*7*64, 1024])),
    # 1024 inputs, 10 outputs (class prediction)
    'out': tf.Variable(tf.random_normal([1024, n_classes]))
}

biases = {
    'bc1': tf.Variable(tf.random_normal([32])),
    'bc2': tf.Variable(tf.random_normal([64])),
    'bd1': tf.Variable(tf.random_normal([1024])),
    'out': tf.Variable(tf.random_normal([n_classes]))
}

# Construct model
pred = conv_net(x, weights, biases, keep_prob)

# Define loss and optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=pred, labels=y))
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(cost)

# Evaluate model
correct_pred = tf.equal(tf.argmax(pred, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

# Initializing the variables
init = tf.global_variables_initializer()
# Out:
# WARNING:tensorflow:From <ipython-input-7-093cc5b41751>:24: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See @{tf.nn.softmax_cross_entropy_with_logits_v2}.

# %%
# Launch the graph
with tf.Session() as sess:
    sess.run(init)
    step = 1
    # Keep training until reach max iterations
    while step * batch_size < training_iters:
        batch_x, batch_y = mnist.train.next_batch(batch_size)
        # Run optimization op (backprop)
        sess.run(optimizer, feed_dict={x: batch_x, y: batch_y,
                                       keep_prob: dropout})
        if step % display_step == 0:
            # Calculate batch loss and accuracy
            loss, acc = sess.run([cost, accuracy], feed_dict={x: batch_x,
                                                              y: batch_y,
                                                              keep_prob: 1.})
            print("Iter " + str(step*batch_size) + ", Minibatch Loss= " + \
                  "{:.6f}".format(loss) + ", Training Accuracy= " + \
                  "{:.5f}".format(acc))
        step += 1
    print("Optimization Finished!")

    # Calculate accuracy for 256 mnist test images
    print("Testing Accuracy:", \
        sess.run(accuracy, feed_dict={x: mnist.test.images[:256],
                                      y: mnist.test.labels[:256],
                                      keep_prob: 1.}))
# Out:
# Iter 1280, Minibatch Loss= 25206.261719, Training Accuracy= 0.27344
# Iter 2560, Minibatch Loss= 11158.732422, Training Accuracy= 0.46875
# Iter 3840, Minibatch Loss= 5476.475586, Training Accuracy= 0.71094
# Iter 5120, Minibatch Loss= 5257.539551, Training Accuracy= 0.69531
# Iter 6400, Minibatch Loss= 3663.018066, Training Accuracy= 0.78906
# Iter 7680, Minibatch Loss= 2602.932129, Training Accuracy= 0.80469
# Iter 8960, Minibatch Loss= 2046.976196, Training Accuracy= 0.85938
# Iter 10240, Minibatch Loss= 4052.697021, Training Accuracy= 0.80469
# Iter 11520, Minibatch Loss= 2944.110840, Training Accuracy= 0.82812
# Iter 12800, Minibatch Loss= 2067.766357, Training Accuracy= 0.87500
# Iter 14080, Minibatch Loss= 1334.779053, Training Accuracy= 0.92188
# Iter 15360, Minibatch Loss= 1942.644531, Training Accuracy= 0.90625
# Iter 16640, Minibatch Loss= 1402.522339, Training Accuracy= 0.90625
# Iter 17920, Minibatch Loss= 1830.195557, Training Accuracy= 0.89062
# Iter 19200, Minibatch Loss= 2092.083008, Training Accuracy= 0.93750
# Iter 20480, Minibatch Loss= 822.120056, Training Accuracy= 0.90625
# Iter 21760, Minibatch Loss= 1385.882812, Training Accuracy= 0.94531
# Iter 23040, Minibatch Loss= 746.429443, Training Accuracy= 0.89062
# Iter 24320, Minibatch Loss= 444.570679, Training Accuracy= 0.94531
# Iter 25600, Minibatch Loss= 1015.508911, Training Accuracy= 0.92969
# Iter 26880, Minibatch Loss= 932.624512, Training Accuracy= 0.90625
# Iter 28160, Minibatch Loss= 583.801270, Training Accuracy= 0.92188
# Iter 29440, Minibatch Loss= 633.476501, Training Accuracy= 0.92969
# Iter 30720, Minibatch Loss= 538.261475, Training Accuracy= 0.93750
# Iter 32000, Minibatch Loss= 1915.407593, Training Accuracy= 0.85938
# Iter 33280, Minibatch Loss= 1848.981079, Training Accuracy= 0.90625
# Iter 34560, Minibatch Loss= 609.382812, Training Accuracy= 0.96094
# Iter 35840, Minibatch Loss= 1026.400146, Training Accuracy= 0.95312
# Iter 37120, Minibatch Loss= 1513.765625, Training Accuracy= 0.89062
# Iter 38400, Minibatch Loss= 827.452759, Training Accuracy= 0.94531
# Iter 39680, Minibatch Loss= 321.896973, Training Accuracy= 0.97656
# Iter 40960, Minibatch Loss= 1147.742676, Training Accuracy= 0.93750
# Iter 42240, Minibatch Loss= 424.941223, Training Accuracy= 0.95312
# Iter 43520, Minibatch Loss= 1068.105591, Training Accuracy= 0.93750
# Iter 44800, Minibatch Loss= 610.162781, Training Accuracy= 0.93750
# Iter 46080, Minibatch Loss= 1023.749084, Training Accuracy= 0.93750
# Iter 47360, Minibatch Loss= 698.310303, Training Accuracy= 0.95312
# Iter 48640, Minibatch Loss= 205.437302, Training Accuracy= 0.96875
# Iter 49920, Minibatch Loss= 600.771423, Training Accuracy= 0.94531
# Iter 51200, Minibatch Loss= 632.056213, Training Accuracy= 0.96094
# Iter 52480, Minibatch Loss= 466.500061, Training Accuracy= 0.96094
# Iter 53760, Minibatch Loss= 152.087601, Training Accuracy= 0.98438
# Iter 55040, Minibatch Loss= 794.123657, Training Accuracy= 0.96875
# Iter 56320, Minibatch Loss= 304.646301, Training Accuracy= 0.96094
# Iter 57600, Minibatch Loss= 374.274231, Training Accuracy= 0.96875
# Iter 58880, Minibatch Loss= 515.796997, Training Accuracy= 0.93750
# Iter 60160, Minibatch Loss= 368.169250, Training Accuracy= 0.94531
# Iter 61440, Minibatch Loss= 343.135681, Training Accuracy= 0.96094
# Iter 62720, Minibatch Loss= 707.517578, Training Accuracy= 0.96875
# Iter 64000, Minibatch Loss= 234.159790, Training Accuracy= 0.98438
# Iter 65280, Minibatch Loss= 1186.301636, Training Accuracy= 0.90625
# Iter 66560, Minibatch Loss= 858.986450, Training Accuracy= 0.92969
# Iter 67840, Minibatch Loss= 659.792542, Training Accuracy= 0.95312
# Iter 69120, Minibatch Loss= 920.577881, Training Accuracy= 0.91406
# Iter 70400, Minibatch Loss= 256.886230, Training Accuracy= 0.96094
# Iter 71680, Minibatch Loss= 159.748795, Training Accuracy= 0.95312
# Iter 72960, Minibatch Loss= 764.699585, Training Accuracy= 0.92969
# Iter 74240, Minibatch Loss= 325.805756, Training Accuracy= 0.96094
# Iter 75520, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# Iter 76800, Minibatch Loss= 170.614746, Training Accuracy= 0.97656
# Iter 78080, Minibatch Loss= 202.147186, Training Accuracy= 0.96875
# Iter 79360, Minibatch Loss= 384.424164, Training Accuracy= 0.95312
# Iter 80640, Minibatch Loss= 464.004395, Training Accuracy= 0.96094
# Iter 81920, Minibatch Loss= 745.483643, Training Accuracy= 0.92188
# Iter 83200, Minibatch Loss= 222.271500, Training Accuracy= 0.96875
# Iter 84480, Minibatch Loss= 381.444824, Training Accuracy= 0.96875
# Iter 85760, Minibatch Loss= 297.500671, Training Accuracy= 0.94531
# Iter 87040, Minibatch Loss= 109.318237, Training Accuracy= 0.98438
# Iter 88320, Minibatch Loss= 1029.633789, Training Accuracy= 0.91406
# Iter 89600, Minibatch Loss= 411.105377, Training Accuracy= 0.95312
# Iter 90880, Minibatch Loss= 139.785095, Training Accuracy= 0.97656
# Iter 92160, Minibatch Loss= 182.646271, Training Accuracy= 0.96875
# Iter 93440, Minibatch Loss= 608.260864, Training Accuracy= 0.95312
# Iter 94720, Minibatch Loss= 476.573639, Training Accuracy= 0.91406
# Iter 96000, Minibatch Loss= 469.521698, Training Accuracy= 0.94531
# Iter 97280, Minibatch Loss= 496.830139, Training Accuracy= 0.92188
# Iter 98560, Minibatch Loss= 34.755482, Training Accuracy= 0.98438
# Iter 99840, Minibatch Loss= 195.996002, Training Accuracy= 0.97656
# Iter 101120, Minibatch Loss= 200.415619, Training Accuracy= 0.96875
# Iter 102400, Minibatch Loss= 5.869682, Training Accuracy= 0.99219
# Iter 103680, Minibatch Loss= 1101.350464, Training Accuracy= 0.95312
# Iter 104960, Minibatch Loss= 218.931717, Training Accuracy= 0.98438
# Iter 106240, Minibatch Loss= 152.545502, Training Accuracy= 0.96875
# Iter 107520, Minibatch Loss= 442.061005, Training Accuracy= 0.96094
# Iter 108800, Minibatch Loss= 141.999374, Training Accuracy= 0.98438
# Iter 110080, Minibatch Loss= 44.212227, Training Accuracy= 0.99219
# Iter 111360, Minibatch Loss= 184.259216, Training Accuracy= 0.96094
# Iter 112640, Minibatch Loss= 280.950409, Training Accuracy= 0.96875
# Iter 113920, Minibatch Loss= 176.886459, Training Accuracy= 0.93750
# Iter 115200, Minibatch Loss= 179.604355, Training Accuracy= 0.96875
# Iter 116480, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# Iter 117760, Minibatch Loss= 258.493164, Training Accuracy= 0.96875
# Iter 119040, Minibatch Loss= 666.532715, Training Accuracy= 0.92969
# Iter 120320, Minibatch Loss= 282.815674, Training Accuracy= 0.98438
# Iter 121600, Minibatch Loss= 337.957642, Training Accuracy= 0.96875
# Iter 122880, Minibatch Loss= 29.631302, Training Accuracy= 0.98438
# Iter 124160, Minibatch Loss= 503.496643, Training Accuracy= 0.96094
# Iter 125440, Minibatch Loss= 63.019829, Training Accuracy= 0.96875
# Iter 126720, Minibatch Loss= 123.870697, Training Accuracy= 0.98438
# Iter 128000, Minibatch Loss= 179.838104, Training Accuracy= 0.97656
# Iter 129280, Minibatch Loss= 182.880280, Training Accuracy= 0.96875
# Iter 130560, Minibatch Loss= 41.651733, Training Accuracy= 0.99219
# Iter 131840, Minibatch Loss= 385.602295, Training Accuracy= 0.96875
# Iter 133120, Minibatch Loss= 788.771606, Training Accuracy= 0.93750
# Iter 134400, Minibatch Loss= 253.299362, Training Accuracy= 0.96875
# Iter 135680, Minibatch Loss= 33.470154, Training Accuracy= 0.98438
# Iter 136960, Minibatch Loss= 202.544724, Training Accuracy= 0.96094
# Iter 138240, Minibatch Loss= 315.643890, Training Accuracy= 0.96094
# Iter 139520, Minibatch Loss= 696.035400, Training Accuracy= 0.92188
# Iter 140800, Minibatch Loss= 201.551697, Training Accuracy= 0.99219
# Iter 142080, Minibatch Loss= 434.183502, Training Accuracy= 0.96094
# Iter 143360, Minibatch Loss= 284.991943, Training Accuracy= 0.96875
# Iter 144640, Minibatch Loss= 232.200623, Training Accuracy= 0.96875
# Iter 145920, Minibatch Loss= 180.167084, Training Accuracy= 0.95312
# Iter 147200, Minibatch Loss= 124.053543, Training Accuracy= 0.96875
# Iter 148480, Minibatch Loss= 50.204758, Training Accuracy= 0.97656
# Iter 149760, Minibatch Loss= 4.875381, Training Accuracy= 0.99219
# Iter 151040, Minibatch Loss= 311.980225, Training Accuracy= 0.95312
# Iter 152320, Minibatch Loss= 75.482910, Training Accuracy= 0.99219
# Iter 153600, Minibatch Loss= 200.231964, Training Accuracy= 0.97656
# Iter 154880, Minibatch Loss= 347.408295, Training Accuracy= 0.96875
# Iter 156160, Minibatch Loss= 161.444427, Training Accuracy= 0.98438
# Iter 157440, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# Iter 158720, Minibatch Loss= 262.972107, Training Accuracy= 0.96094
# Iter 160000, Minibatch Loss= 251.116821, Training Accuracy= 0.96875
# Iter 161280, Minibatch Loss= 293.155273, Training Accuracy= 0.95312
# Iter 162560, Minibatch Loss= 125.187431, Training Accuracy= 0.96875
# Iter 163840, Minibatch Loss= 209.545898, Training Accuracy= 0.96094
# Iter 165120, Minibatch Loss= 447.211945, Training Accuracy= 0.93750
# Iter 166400, Minibatch Loss= 120.575859, Training Accuracy= 0.96875
# Iter 167680, Minibatch Loss= 85.991066, Training Accuracy= 0.96875
# Iter 168960, Minibatch Loss= 69.658447, Training Accuracy= 0.98438
# Iter 170240, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# Iter 171520, Minibatch Loss= 90.872154, Training Accuracy= 0.97656
# Iter 172800, Minibatch Loss= 223.042633, Training Accuracy= 0.97656
# Iter 174080, Minibatch Loss= 94.388855, Training Accuracy= 0.98438
# Iter 175360, Minibatch Loss= 125.202782, Training Accuracy= 0.98438
# Iter 176640, Minibatch Loss= 25.146400, Training Accuracy= 0.99219
# Iter 177920, Minibatch Loss= 38.569855, Training Accuracy= 0.97656
# Iter 179200, Minibatch Loss= 224.930847, Training Accuracy= 0.95312
# Iter 180480, Minibatch Loss= 12.373947, Training Accuracy= 0.99219
# Iter 181760, Minibatch Loss= 273.237183, Training Accuracy= 0.95312
# Iter 183040, Minibatch Loss= 63.158356, Training Accuracy= 0.97656
# Iter 184320, Minibatch Loss= 59.675125, Training Accuracy= 0.96875
# Iter 185600, Minibatch Loss= 227.429031, Training Accuracy= 0.96875
# Iter 186880, Minibatch Loss= 104.761398, Training Accuracy= 0.98438
# Iter 188160, Minibatch Loss= 212.252136, Training Accuracy= 0.95312
# Iter 189440, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# Iter 190720, Minibatch Loss= 39.968880, Training Accuracy= 0.97656
# Iter 192000, Minibatch Loss= 106.105865, Training Accuracy= 0.97656
# Iter 193280, Minibatch Loss= 82.999939, Training Accuracy= 0.96094
# Iter 194560, Minibatch Loss= 53.034019, Training Accuracy= 0.99219
# Iter 195840, Minibatch Loss= 123.712341, Training Accuracy= 0.97656
# Iter 197120, Minibatch Loss= 131.496841, Training Accuracy= 0.98438
# Iter 198400, Minibatch Loss= 215.611374, Training Accuracy= 0.98438
# Iter 199680, Minibatch Loss= 47.689453, Training Accuracy= 0.98438
# Optimization Finished!
# Testing Accuracy: 0.99609375
